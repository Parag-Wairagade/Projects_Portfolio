# %% [markdown]
# #  Investigating Hotel Business By Data Visualization

# %%
# importing libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
# importing data

df = pd.read_csv("Hotel_Booking.csv")

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2017          September
# 1  Resort Hotel            0        737               2017          September
# 2  Resort Hotel            0          7               2017          September
# 3  Resort Hotel            0         13               2017          September
# 4  Resort Hotel            0         14               2017          September
# 5  Resort Hotel            0         14               2017          September
# 6  Resort Hotel            0          0               2017          September
# 7  Resort Hotel            0          9               2017          September
# 8  Resort Hotel            1         85               2017          September
# 9  Resort Hotel            1         75               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 51051     City Hotel            1        309               2018
# 26722   Resort Hotel            0         51               2018
# 104975    City Hotel            0         79               2019
# 4575    Resort Hotel            0        162               2018
# 26593   Resort Hotel            0        191               2018
# 53567     City Hotel            1        234               2018
# 111408    City Hotel            0          0               2019
# 14978   Resort Hotel            1        166               2017
# 33427   Resort Hotel            0         23               2019
# 14607   Resort Hotel            0         51               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 51051                July                        20
# 26722             October                        32
# 104975              March                         4
# ...

# %%
df.shape
# Out:
# (119390, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# we need to change data type of children becuase it should be int not float

df.children = df.children.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  int32
#  11  babies                          119390 non-null  int64
# ...

# %%
# checking null values
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_weekdays_nights          0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# city                              0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# we have to replace null values

df.children.fillna(0, inplace = True)
df.city.fillna('undefined', inplace = True)
df.agent.fillna(0, inplace = True)
df.company.fillna(0, inplace = True)

# %%
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_weekdays_nights          0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# city                              0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# checking Duplicate values

df.duplicated().sum()
# Out:
# 33261

# %%
# droping Duplicates

df.drop_duplicates(keep='first', inplace = True)

# %%
# checking Duplicate values

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Visulazation

# %%
df_1 = df.groupby('hotel')[['hotel']].count()
df_1.columns = ['Total']
df_1.reset_index(inplace=True)
df_1
# Out:
#           hotel  Total
# 0    City Hotel  52575
# 1  Resort Hotel  33554

# %%
plt.figure(figsize=(12,8))
sns.set()
plt.pie( df_1.Total, labels = df_1.hotel, autopct = '%.2f%%', radius = .8, startangle = 90, 
        wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, colors = ['g','b'])

plt.title('Total Hotel Bookings', fontdict = {'fontsize' : 20, 'fontweight' : 'bold'})
plt.legend(labelcolor = ['g','b'])
plt.show()

# %% [markdown]
# * **City Hotel** is booked more than **Resort Hotel**

# %% [markdown]
# #  Ratio Of Monthly Booking

# %%
df_2 = df.groupby(['hotel', 'arrival_date_month'])[['arrival_date_month']].count()
df_2.columns = ['Total']
df_2.reset_index(inplace=True)
df_2.sort_values('Total', ascending = False, inplace = True)
df_2
# Out:
#            hotel arrival_date_month  Total
# 10    City Hotel            October   6503
# 11    City Hotel          September   5686
# 5     City Hotel               July   5345
# 6     City Hotel               June   5035
# 1     City Hotel             August   4927
# 8     City Hotel                May   4821
# 22  Resort Hotel            October   4647
# 23  Resort Hotel          September   4300
# 9     City Hotel           November   4063
# 2     City Hotel           December   4059
# 0     City Hotel              April   3560
# 3     City Hotel           February   2983
# 17  Resort Hotel               July   2897
# 4     City Hotel            January   2895
# 18  Resort Hotel               June   2776
# 13  Resort Hotel             August   2730
# 7     City Hotel              March   2698
# 14  Resort Hotel           December   2660
# 20  Resort Hotel                May   2614
# 12  Resort Hotel              April   2475
# 21  Resort Hotel           November   2394
# ...

# %%
plt.figure(figsize = (16,8))
sns.lineplot(x = df_2.arrival_date_month, y = df_2.Total, hue = df_2.hotel, style = df_2.hotel, palette = ['g','b'],
             dashes = False, markers = ["o","<"])

plt.title("Total Hotel Booking By Months", fontdict = {'fontsize' : 20, 'fontweight' : 'bold'})
plt.xlabel("Months", fontdict = {'fontsize' : 10, 'fontweight' : 'bold'})
plt.ylabel("Total Bookings", fontdict = {'fontsize' : 10, 'fontweight' : 'bold'})
plt.show()

# %% [markdown]
# * We can see that in **October** and **September** we got **Highest** number of Bookings.
# * Also, **July** and **June** have **Moderate** number of Bookings.
# * In **March** we got **Lowest** number of Bookings.

# %% [markdown]
# # Total Cancelation

# %%
df_city = df[df.hotel == 'City Hotel']
df_resort = df[df.hotel == 'Resort Hotel']

c_city = df_city.groupby('is_canceled')[['is_canceled']].count()
c_city.columns = ['Total']
c_city.reset_index(inplace=True)

c_resort = df_resort.groupby('is_canceled')[['is_canceled']].count()
c_resort.columns = ['Total']
c_resort.reset_index(inplace=True)

x = {0 : 'Not Canceled', 1 : 'Canceled'}

c_city.is_canceled = c_city.is_canceled.map(x)
c_resort.is_canceled = c_resort.is_canceled.map(x)

# %%
c_city
# Out:
#     is_canceled  Total
# 0  Not Canceled  36721
# 1      Canceled  15854

# %%
c_resort
# Out:
#     is_canceled  Total
# 0  Not Canceled  25672
# 1      Canceled   7882

# %%
plt.figure(figsize = (12,8))
plt.pie( c_city.Total, labels = c_city.is_canceled, autopct = '%.2f%%', radius = .8, startangle = 90, 
        wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, colors = ['g','b'])

plt.title('Total Hotel Bookings', fontdict = {'fontsize' : 20, 'fontweight' : 'bold'})
plt.legend(labelcolor = ['g','b'])
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.pie( c_resort.Total, labels = c_resort.is_canceled, autopct = '%.2f%%', radius = .8, startangle = 90, 
        wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, colors = ['g','b'])

plt.title('Total Hotel Bookings', fontdict = {'fontsize' : 20, 'fontweight' : 'bold'})
plt.legend(labelcolor = ['g','b'])
plt.show()

# %% [markdown]
# * In **City Hotels** canceletions rate is much **Higher** than **Resort Hotels**.

# %% [markdown]
# # Total Stay Duration

# %%
df['total_stay_duration'] = df.stays_in_weekend_nights + df.stays_in_weekdays_nights
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2017
# 1       Resort Hotel            0        737               2017
# 2       Resort Hotel            0          7               2017
# 3       Resort Hotel            0         13               2017
# 4       Resort Hotel            0         14               2017
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2019
# 119386    City Hotel            0        102               2019
# 119387    City Hotel            0         34               2019
# 119388    City Hotel            0        109               2019
# 119389    City Hotel            0        205               2019
#
#        arrival_date_month  arrival_date_week_number  \
# 0               September                        27
# 1               September                        27
# ...

# %%
df['total_stay_duration'].max()
# Out:
# 69

# %%
df['total_stay_duration'].min()
# Out:
# 0

# %% [markdown]
# * So, the guests stayed betweem min. 0 to max 69 days.

# %%
df['total_stay_week'] = np.where(df.total_stay_duration < 8, '<1',
                                 np.where(df.total_stay_duration < 15, '1-2',
                                 np.where(df.total_stay_duration < 22, '2-3',
                                 np.where(df.total_stay_duration < 29, '3-4', '>4'))))
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2017
# 1       Resort Hotel            0        737               2017
# 2       Resort Hotel            0          7               2017
# 3       Resort Hotel            0         13               2017
# 4       Resort Hotel            0         14               2017
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2019
# 119386    City Hotel            0        102               2019
# 119387    City Hotel            0         34               2019
# 119388    City Hotel            0        109               2019
# 119389    City Hotel            0        205               2019
#
#        arrival_date_month  arrival_date_week_number  \
# 0               September                        27
# 1               September                        27
# ...

# %%
df_3 = df.groupby(['hotel','total_stay_week'])[['hotel']].count()
df_3.columns = ['Total']
df_3.reset_index(inplace = True)
df_3.sort_values('Total', ascending = False, inplace = True)
df_3
# Out:
#           hotel total_stay_week  Total
# 3    City Hotel              <1  51394
# 8  Resort Hotel              <1  29887
# 5  Resort Hotel             1-2   3453
# 0    City Hotel             1-2   1026
# 6  Resort Hotel             2-3    134
# 1    City Hotel             2-3    103
# 7  Resort Hotel             3-4     56
# 2    City Hotel             3-4     28
# 4    City Hotel              >4     24
# 9  Resort Hotel              >4     24

# %%
plt.figure(figsize = (16,8))
sns.set()
sns.lineplot(x = df_3.total_stay_week, y = df_3.Total, hue = df_3.hotel, style = df_3.hotel, palette = ['g','b'],
             dashes = False, markers = ["o","<"])

plt.title("Total No Of Week Bookings", fontdict = {'fontsize' : 20, 'fontweight' : 'bold'})
plt.xlabel("Weeks", fontdict = {'fontsize' : 10, 'fontweight' : 'bold'})
plt.ylabel("Total Bookings", fontdict = {'fontsize' : 10, 'fontweight' : 'bold'})
plt.show()

# %% [markdown]
# * Most of the guests book hotels for not more than **1 Week**.
# * Some of the guests book hotels for **1 to 2 Weeks**.
# * Very few guests book hotels for  more than **2 Weeks**.

# %% [markdown]
# # Repeated Guest

# %%
r_city = df_city.groupby('is_repeated_guest')[['is_repeated_guest']].count()
r_city.columns = ['Total']
r_city.reset_index(inplace=True)

r_resort = df_resort.groupby('is_repeated_guest')[['is_repeated_guest']].count()
r_resort.columns = ['Total']
r_resort.reset_index(inplace=True)

x = {0 : 'Not Repeated', 1 : 'Repeated'}

r_city.is_repeated_guest = r_city.is_repeated_guest.map(x)
r_resort.is_repeated_guest = r_resort.is_repeated_guest.map(x)

# %%
r_city
# Out:
#   is_repeated_guest  Total
# 0      Not Repeated  50875
# 1          Repeated   1700

# %%
r_resort
# Out:
#   is_repeated_guest  Total
# 0      Not Repeated  31852
# 1          Repeated   1702

# %%
plt.figure(figsize = (12,8))
plt.pie( r_city.Total, labels = r_city.is_repeated_guest, autopct = '%.2f%%', radius = .8, startangle = 90, 
        wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, colors = ['g','b'])

plt.title('Total Hotel Repeated Bookings', fontdict = {'fontsize' : 20, 'fontweight' : 'bold'})
plt.legend(labelcolor = ['g','b'])
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.pie( r_resort.Total, labels = r_resort.is_repeated_guest, autopct = '%.2f%%', radius = .8, startangle = 90, 
        wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, colors = ['g','b'])

plt.title('Total Hotel Repeated Bookings', fontdict = {'fontsize' : 20, 'fontweight' : 'bold'})
plt.legend(labelcolor = ['g','b'])
plt.show()

# %% [markdown]
# * Their are very few guest who comes repetedly to a perticular hotels.
# * In **Resort hotels** repeated guest booking are more compare to **City Hotels**.
